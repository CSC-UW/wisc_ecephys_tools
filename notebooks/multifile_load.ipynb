# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import numpy as np

# %%
from ecephys_analyses.data import paths
from ecephys.sglx_utils import load_timeseries, load_multifile_timeseries

# %%
bin_paths = paths.get_sglx_style_datapaths("Eugene", "extended-wake", "lf.bin")

# %%
da = load_multifile_timeseries(bin_paths[0:3], chans=[0, 1], contiguous=True)
# Out:
# nChan: 385, nFileSamp: 800217
# nChan: 385, nFileSamp: 2877424
# nChan: 385, nFileSamp: 2430722

# %%
da.plot(x="time", aspect=10, size=3)

# %%
da = load_multifile_timeseries(bin_paths[0:3], chans=[0, 1], contiguous=False)
# Out:
# nChan: 385, nFileSamp: 800217
# nChan: 385, nFileSamp: 2877424
# nChan: 385, nFileSamp: 2430722

# %%
da.plot(x="time", aspect=10, size=3)

# %%
da.sel(time=slice(*[None, None]))
# Out:
# <xarray.DataArray (time: 6108363, channel: 2)>
# array([[-107.8125,  -89.0625],
#        [ -65.625 ,   -9.375 ],
#        [ -28.125 ,   65.625 ],
#        ...,
#        [ -23.4375,    0.    ],
#        [ -18.75  ,  -46.875 ],
#        [ -28.125 ,  -46.875 ]])
# Coordinates:
#   * time     (time) datetime64[ns] 2020-09-25T09:23:15 ... 2020-09-25T10:20:3...
#   * channel  (channel) int64 0 1
# Attributes:
#     units:             uV
#     fs:                2500.0069173333336
#     file_create_time:  2020-09-25 09:23:15
#     first_sample:      2582160

# %%
da
# Out:
# <xarray.DataArray (time: 6108363, channel: 2)>
# array([[-107.8125,  -89.0625],
#        [ -65.625 ,   -9.375 ],
#        [ -28.125 ,   65.625 ],
#        ...,
#        [ -23.4375,    0.    ],
#        [ -18.75  ,  -46.875 ],
#        [ -28.125 ,  -46.875 ]])
# Coordinates:
#   * time     (time) datetime64[ns] 2020-09-25T09:23:15 ... 2020-09-25T10:20:3...
#   * channel  (channel) int64 0 1
# Attributes:
#     units:             uV
#     fs:                2500.0069173333336
#     file_create_time:  2020-09-25 09:23:15
#     first_sample:      2582160
