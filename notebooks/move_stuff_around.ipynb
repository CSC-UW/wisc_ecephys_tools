# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import pandas as pd
from ecephys_analyses.data import paths

from ecephys import sglx_utils

# %% [markdown]
# # Stim_times.txt

# %%
### Allan

# %%
# simple conditions

# %%
conditions =  [
#     '3-5-2021_g0_imec0',
#     '3-5-2021_g0_imec1',
    '3-5-2021_g2_imec0',
    '3-5-2021_g2_imec1',
    '3-5-2021_g3_imec0',
    '3-5-2021_g3_imec1',
#     '3-5-2021_g4_imec0',
#     '3-5-2021_g4_imec1',
#     '3-5-2021_g5_imec0',
#     '3-5-2021_g5_imec1',
#     '3-5-2021_g6_imec0',
#     '3-5-2021_g6_imec1',
]
print(conditions)
# Out:
# ['3-5-2021_g2_imec0', '3-5-2021_g2_imec1', '3-5-2021_g3_imec0', '3-5-2021_g3_imec1']

# %%
for cond in conditions:
    path = paths.get_datapath('Allan', cond, 'dummy')
    print(path.parent)
    path.parent.mkdir()
# Out:
# /Volumes/neuropixel/Data/tom/catgt/CNPIX8-Allan/3-5-2021_g2_imec0
# /Volumes/neuropixel/Data/tom/catgt/CNPIX8-Allan/3-5-2021_g2_imec1
# /Volumes/neuropixel/Data/tom/catgt/CNPIX8-Allan/3-5-2021_g3_imec0
# /Volumes/neuropixel/Data/tom/catgt/CNPIX8-Allan/3-5-2021_g3_imec1

# %%
# Combined

# %%
combined_cond = '3-5-2021_g2-3_imec1'
conditions =  paths.load_datapath_yaml()['Allan'][combined_cond]
print(conditions)
# Out:
# ['3-5-2021_g2_imec1', '3-5-2021_g3_imec1']

# %%
dfs = []
start_time = 0
for cond in conditions:
    print(cond, 'start time', start_time)
    path = paths.get_datapath('Allan', cond, 'stim_times.csv')
    df = pd.read_csv(path)
    df['sglx_stim_time'] = df['sglx_stim_time'] + start_time
    dfs.append(df)
    binpaths = paths.get_sglx_style_datapaths('Allan', cond, 'ap.bin', catgt_data=True)
    assert len(binpaths) == 1
    start_time = float(sglx_utils.get_meta(binpaths[0])['fileTimeSecs'])
df_combined = pd.concat(dfs)
    
#     end_time 
#     df
#     print(path.exists())
#     print(path)
# Out:
# 3-5-2021_g2_imec1 start time 0
# 3-5-2021_g3_imec1 start time 1087.0443558685154

# %%
save_path = paths.get_datapath('Allan', combined_cond, 'stim_times.csv')
save_path
# Out:
# PosixPath('/Volumes/neuropixel/Data/tom/catgt/CNPIX8-Allan/3-5-2021_g2-3_imec1/stim_times.csv')

# %%
df_combined.to_csv(save_path, index=False)

# %%
### EUGENE

# %%
eugene = pd.read_excel('Eugene.xlsx', engine='openpyxl')

# %%
eugene.columns
# Out:
# Index(['File location(V = neuropixel_archive(\\tononi-nas))', 'State',
#        'Stim Depth (- from surface)', 'stim  location', 'number of trials ',
#        'trials reorded BL'],
#       dtype='object')

# %%
eugene.columns = 'datapath', 'state', 'depth', 'stimpath', 'N_trials', 'trials_reordered_BL'

# %%
eugene['datapath'][0:1].values
# Out:
# array(["  'V:\\Data\\chronic\\CNPIX6-Eugene\\10-9-2020-B\\10.9.2020StimDepN_g0\\'"],
#       dtype=object)

# %%
conditions = paths.get_conditions('Eugene', 'eStim')

# %%
eugene[0:10]
# Out:
#                                             datapath state  depth  \
# 0    'V:\Data\chronic\CNPIX6-Eugene\10-9-2020-B\1...  NREM    1.5
# 1    'V:\Data\chronic\CNPIX6-Eugene\10-19-2020-B\...  NREM    1.5
# 2    'V:\Data\chronic\CNPIX6-Eugene\10-2-2020-B\1...  NREM    1.4
# 3    'V:\Data\chronic\CNPIX6-Eugene\10-9-2020-B\1...  NREM    1.2
# 4    'V:\Data\chronic\CNPIX6-Eugene\10-2-2020-B\1...  NREM    1.1
# 5    'V:\Data\chronic\CNPIX6-Eugene\10-9-2020-B\1...  NREM    0.9
# 6    'V:\Data\chronic\CNPIX6-Eugene\10-2-2020-B\1...  NREM    0.8
# 7    'V:\Data\chronic\CNPIX6-Eugene\10-9-2020-B\1...  NREM    0.6
# 8    'V:\Data\chronic\CNPIX6-Eugene\10-2-2020-B\1...  NREM    0.5
# 9    'V:\Data\chronic\CNPIX6-Eugene\10-9-2020-B\1...  NREM    0.3
#
#                                             stimpath  N_trials  \
# 0    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...        90
# 1     'neuropixel(//tononi-nas):\Data\CNPIX6-Euge...       100
# 2    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...        90
# 3    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...       100
# 4    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...        90
# 5    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...       100
# 6    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...       100
# 7    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...       100
# 8    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...       100
# 9    'neuropixel(//tononi-nas):\Data\CNPIX6-Eugen...        95
#
#   trials_reordered_BL                                             rundir  \
# 0             16--106  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 1             75--175  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 2             10--100  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 3             20--120  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 4             75--165  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 5             30--130  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 6             30--130  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 7             20--120  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 8             45--145  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 9              25-120  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
#
#                         condition
# 0   10-9-2020_NREM_depth1.5_imec1
# 1  10-19-2020_NREM_depth1.5_imec1
# 2   10-2-2020_NREM_depth1.4_imec1
# 3   10-9-2020_NREM_depth1.2_imec1
# 4   10-2-2020_NREM_depth1.1_imec1
# 5   10-9-2020_NREM_depth0.9_imec1
# 6   10-2-2020_NREM_depth0.8_imec1
# 7   10-9-2020_NREM_depth0.6_imec1
# 8   10-2-2020_NREM_depth0.5_imec1
# 9   10-9-2020_NREM_depth0.3_imec1

# %%
# add condition dir to run path

for cond in conditions: 
    pathname = paths.get_sglx_style_datapaths('Eugene', cond, 'ap.bin')[0]
    rundir = pathname.parents[1]
    run = rundir.name
    for i, row in eugene.iterrows():
        path = row['datapath']
        assert rundir not in eugene.columns or eugene.iloc[i, 'rundir'] is None 
        if run in path:
            eugene.loc[i, 'rundir'] = rundir
            eugene.loc[i, 'condition'] = cond.split('_imec')[0]

# %%
eugene['condition']
# Out:
# 0      10-9-2020_NREM_depth1.5
# 1     10-19-2020_NREM_depth1.5
# 2      10-2-2020_NREM_depth1.4
# 3      10-9-2020_NREM_depth1.2
# 4      10-2-2020_NREM_depth1.1
# 5      10-9-2020_NREM_depth0.9
# 6      10-2-2020_NREM_depth0.8
# 7      10-9-2020_NREM_depth0.6
# 8      10-2-2020_NREM_depth0.5
# 9      10-9-2020_NREM_depth0.3
# 10     10-2-2020_NREM_depth0.2
# 11     10-19-2020_REM_depth1.5
# 12     10-2-2020_Wake_depth1.5
# 13     10-9-2020_Wake_depth1.4
# 14     10-2-2020_Wake_depth1.2
# 15     10-9-2020_Wake_depth1.1
# 16     10-2-2020_Wake_depth0.9
# 17     10-9-2020_Wake_depth0.8
# 18     10-2-2020_Wake_depth0.6
# 19     10-9-2020_Wake_depth0.5
# 20     10-2-2020_Wake_depth0.3
# 21     10-9-2020_Wake_depth0.2
# 22     10-2-2020_Sevo_depth1.5
# 23     10-9-2020_Sevo_depth1.4
# 24     10-2-2020_Sevo_depth1.2
# 25     10-9-2020_Sevo_depth1.1
# 26     10-2-2020_Sevo_depth0.9
# 27     10-9-2020_Sevo_depth0.8
# 28     10-2-2020_Sevo_depth0.6
# 29     10-9-2020_Sevo_depth0.5
# 30     10-2-2020_Sevo_depth0.3
# 31     10-9-2020_Sevo_depth0.2
# Name: condition, dtype: object

# %%
import numpy as np

# for i, row in eugene.iterrows():
for cond in conditions:
    for i, row in eugene.iterrows():
        if row['condition'] not in cond:
            continue
        stimpath = row['stimpath'].split('CNPIX6-Eugene')[1].replace('\\', '/').replace("'", '')

        stimpath = Path('/Volumes/neuropixel/Data/CNPIX6-Eugene' + stimpath)
    #     print(stimpath, stimpath.exists())

        stim_times = pd.read_csv(stimpath, header=None)

        df = pd.DataFrame({'sglx_stim_time': np.concatenate(stim_times.values), 'stim_state': row['state']})
        print(df[0:5])

    #     dfpath = path.get_filename()
        df_path = paths.get_datapath('Eugene', cond, 'stim_times.csv')
        print(df_path)

        df.to_csv(df_path, index=False)

    #     if i > 3:
    #         break
    #     stimtimes =
# Out:
#    sglx_stim_time stim_state
# 0       354.82929       NREM
# 1       556.73249       NREM
# 2       338.82939       NREM
# 3       286.82971       NREM
# 4       314.82954       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth1.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       354.82929       NREM
# 1       556.73249       NREM
# 2       338.82939       NREM
# 3       286.82971       NREM
# 4       314.82954       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth1.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       992.97431       NREM
# 1      1000.97430       NREM
# 2      1162.64360       NREM
# 3       786.38527       NREM
# 4       746.38552       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-19-2020_NREM_depth1.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       992.97431       NREM
# 1      1000.97430       NREM
# 2      1162.64360       NREM
# 3       786.38527       NREM
# 4       746.38552       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-19-2020_NREM_depth1.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       405.80783       NREM
# 1       307.49267       NREM
# 2       648.71012       NREM
# 3       732.70960       NREM
# 4       704.70978       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth1.4_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       405.80783       NREM
# 1       307.49267       NREM
# 2       648.71012       NREM
# 3       732.70960       NREM
# 4       704.70978       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth1.4_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0      1190.43800       NREM
# 1      1286.43740       NREM
# 2       414.80779       NREM
# 3       696.59992       NREM
# 4       390.80794       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth1.2_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0      1190.43800       NREM
# 1      1286.43740       NREM
# 2       414.80779       NREM
# 3       696.59992       NREM
# 4       390.80794       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth1.2_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       1147.1819       NREM
# 1       2273.7242       NREM
# 2       1239.1813       NREM
# 3       2241.7244       NREM
# 4       2265.7242       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth1.1_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       1147.1819       NREM
# 1       2273.7242       NREM
# 2       1239.1813       NREM
# 3       2241.7244       NREM
# 4       2265.7242       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth1.1_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       549.45353       NREM
# 1       697.45243       NREM
# 2       733.45216       NREM
# 3       793.45172       NREM
# 4       561.45345       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth0.9_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       549.45353       NREM
# 1       697.45243       NREM
# 2       733.45216       NREM
# 3       793.45172       NREM
# 4       561.45345       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth0.9_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       500.57264       NREM
# 1       268.57407       NREM
# 2       472.57281       NREM
# 3       784.57090       NREM
# 4       332.57367       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth0.8_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       500.57264       NREM
# 1       268.57407       NREM
# 2       472.57281       NREM
# 3       784.57090       NREM
# 4       332.57367       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth0.8_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       658.61502       NREM
# 1       526.44426       NREM
# 2       722.61462       NREM
# 3       498.44444       NREM
# 4       362.51004       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth0.6_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       658.61502       NREM
# 1       526.44426       NREM
# 2       722.61462       NREM
# 3       498.44444       NREM
# 4       362.51004       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth0.6_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       388.50370       NREM
# 1       608.50235       NREM
# 2       648.50210       NREM
# 3       248.50456       NREM
# 4       160.50510       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth0.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       388.50370       NREM
# 1       608.50235       NREM
# 2       648.50210       NREM
# 3       248.50456       NREM
# 4       160.50510       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth0.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       251.98517       NREM
# 1       239.98524       NREM
# 2       215.98539       NREM
# 3       315.98477       NREM
# 4       291.98492       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth0.3_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       251.98517       NREM
# 1       239.98524       NREM
# 2       215.98539       NREM
# 3       315.98477       NREM
# 4       291.98492       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_NREM_depth0.3_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       938.05665       NREM
# 1       176.17570       NREM
# 2      1062.48500       NREM
# 3       613.96566       NREM
# 4       462.61061       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth0.2_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       938.05665       NREM
# 1       176.17570       NREM
# 2      1062.48500       NREM
# 3       613.96566       NREM
# 4       462.61061       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_NREM_depth0.2_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       3087.4733        REM
# 1       2917.0687        REM
# 2       3136.8180        REM
# 3       2915.0687        REM
# 4       3103.4732        REM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-19-2020_REM_depth1.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       3087.4733        REM
# 1       2917.0687        REM
# 2       3136.8180        REM
# 3       2915.0687        REM
# 4       3103.4732        REM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-19-2020_REM_depth1.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       431.13122       Wake
# 1       401.13142       Wake
# 2       658.31372       Wake
# 3       838.31250       Wake
# 4       882.31220       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth1.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       431.13122       Wake
# 1       401.13142       Wake
# 2       658.31372       Wake
# 3       838.31250       Wake
# 4       882.31220       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth1.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       695.81294       Wake
# 1       323.81526       Wake
# 2       343.81513       Wake
# 3       327.81523       Wake
# 4       363.81501       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth1.4_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       695.81294       Wake
# 1       323.81526       Wake
# 2       343.81513       Wake
# 3       327.81523       Wake
# 4       363.81501       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth1.4_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       76.667276       Wake
# 1       96.667154       Wake
# 2      368.665500       Wake
# 3      324.665760       Wake
# 4      276.666060       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth1.2_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       76.667276       Wake
# 1       96.667154       Wake
# 2      368.665500       Wake
# 3      324.665760       Wake
# 4      276.666060       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth1.2_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       630.15798       Wake
# 1       338.15981       Wake
# 2       390.15948       Wake
# 3       458.15906       Wake
# 4       426.15926       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth1.1_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       630.15798       Wake
# 1       338.15981       Wake
# 2       390.15948       Wake
# 3       458.15906       Wake
# 4       426.15926       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth1.1_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       581.01655       Wake
# 1       429.01748       Wake
# 2       537.01682       Wake
# 3       233.01868       Wake
# 4       217.01877       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth0.9_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       581.01655       Wake
# 1       429.01748       Wake
# 2       537.01682       Wake
# 3       233.01868       Wake
# 4       217.01877       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth0.9_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       498.93268       Wake
# 1       554.93233       Wake
# 2       438.93306       Wake
# 3       310.93386       Wake
# 4       182.93466       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth0.8_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       498.93268       Wake
# 1       554.93233       Wake
# 2       438.93306       Wake
# 3       310.93386       Wake
# 4       182.93466       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth0.8_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       545.56364       Wake
# 1       581.56341       Wake
# 2       525.56376       Wake
# 3       341.56490       Wake
# 4       541.56366       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth0.6_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       545.56364       Wake
# 1       581.56341       Wake
# 2       525.56376       Wake
# 3       341.56490       Wake
# 4       541.56366       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth0.6_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       379.01367       Wake
# 1       419.01342       Wake
# 2       335.01394       Wake
# 3       451.01323       Wake
# 4       559.01256       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth0.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       379.01367       Wake
# 1       419.01342       Wake
# 2       335.01394       Wake
# 3       451.01323       Wake
# 4       559.01256       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth0.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       413.03015       Wake
# 1       173.03166       Wake
# 2       545.02932       Wake
# 3       433.03002       Wake
# 4       533.02939       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth0.3_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       413.03015       Wake
# 1       173.03166       Wake
# 2       545.02932       Wake
# 3       433.03002       Wake
# 4       533.02939       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Wake_depth0.3_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       315.01443       Wake
# 1       343.01425       Wake
# 2       243.01489       Wake
# 3       331.01433       Wake
# 4       475.01341       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth0.2_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       315.01443       Wake
# 1       343.01425       Wake
# 2       243.01489       Wake
# 3       331.01433       Wake
# 4       475.01341       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Wake_depth0.2_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       643.34611       Sevo
# 1       891.34455       Sevo
# 2       763.34535       Sevo
# 3       827.34495       Sevo
# 4       651.34606       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth1.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       643.34611       Sevo
# 1       891.34455       Sevo
# 2       763.34535       Sevo
# 3       827.34495       Sevo
# 4       651.34606       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth1.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       270.55205       Sevo
# 1       258.55212       Sevo
# 2       214.55239       Sevo
# 3       490.55067       Sevo
# 4       606.54995       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth1.4_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       270.55205       Sevo
# 1       258.55212       Sevo
# 2       214.55239       Sevo
# 3       490.55067       Sevo
# 4       606.54995       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth1.4_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       260.85718       Sevo
# 1       440.85608       Sevo
# 2       432.85613       Sevo
# 3       436.85611       Sevo
# 4       400.85633       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth1.2_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       260.85718       Sevo
# 1       440.85608       Sevo
# 2       432.85613       Sevo
# 3       436.85611       Sevo
# 4       400.85633       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth1.2_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0      337.874610       Sevo
# 1       41.876467       Sevo
# 2      245.875180       Sevo
# 3      385.874300       Sevo
# 4      441.873950       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth1.1_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0      337.874610       Sevo
# 1       41.876467       Sevo
# 2      245.875180       Sevo
# 3      385.874300       Sevo
# 4      441.873950       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth1.1_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       434.11567       Sevo
# 1       194.11714       Sevo
# 2       494.11530       Sevo
# 3       390.11594       Sevo
# 4       414.11579       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth0.9_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       434.11567       Sevo
# 1       194.11714       Sevo
# 2       494.11530       Sevo
# 3       390.11594       Sevo
# 4       414.11579       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth0.9_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       190.15847       Sevo
# 1       382.15726       Sevo
# 2       174.15857       Sevo
# 3       474.15668       Sevo
# 4       254.15807       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth0.8_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       190.15847       Sevo
# 1       382.15726       Sevo
# 2       174.15857       Sevo
# 3       474.15668       Sevo
# 4       254.15807       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth0.8_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0      382.841070       Sevo
# 1      398.840970       Sevo
# 2      466.840560       Sevo
# 3      346.841290       Sevo
# 4       90.842839       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth0.6_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0      382.841070       Sevo
# 1      398.840970       Sevo
# 2      466.840560       Sevo
# 3      346.841290       Sevo
# 4       90.842839       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth0.6_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       302.45091       Sevo
# 1       362.45053       Sevo
# 2       182.45165       Sevo
# 3       434.45009       Sevo
# 4       254.45120       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth0.5_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       302.45091       Sevo
# 1       362.45053       Sevo
# 2       182.45165       Sevo
# 3       434.45009       Sevo
# 4       254.45120       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth0.5_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0       383.25727       Sevo
# 1       391.25722       Sevo
# 2       335.25756       Sevo
# 3       215.25828       Sevo
# 4       307.25773       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth0.3_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0       383.25727       Sevo
# 1       391.25722       Sevo
# 2       335.25756       Sevo
# 3       215.25828       Sevo
# 4       307.25773       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-2-2020_Sevo_depth0.3_imec1/stim_times.csv
#    sglx_stim_time stim_state
# 0      198.075420       Sevo
# 1      162.075640       Sevo
# 2       78.076159       Sevo
# 3      438.073950       Sevo
# 4      246.075130       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth0.2_imec0/stim_times.csv
#    sglx_stim_time stim_state
# 0      198.075420       Sevo
# 1      162.075640       Sevo
# 2       78.076159       Sevo
# 3      438.073950       Sevo
# 4      246.075130       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX6-Eugene/10-9-2020_Sevo_depth0.2_imec1/stim_times.csv

# %%
### Alessandro

# %%
aless = pd.read_excel('Alessandro stim location.xlsx', engine='openpyxl')

# %%
aless.columns
# Out:
# Index(['File location (neuropixel_archive(\\tononi-nas))', 'State',
#        'Stim Depth (- from surface)', 'stim  location', 'number of trials ',
#        'trials reorded BL'],
#       dtype='object')

# %%
aless.columns = 'datapath', 'state', 'depth', 'stimpath', 'N_trials', 'trials_reordered_BL'

# %%
aless['datapath'][0:1].values
# Out:
# array(['Data\\chronic\\CNPIX5-Alessandro\\8-31-2020\\8-31-2020_WEst_g0\\8-31-2020_WEst_g0_imec0\\8-31-2020_WEst_g0_t0.imec0.lf.bin'],
#       dtype=object)

# %%
conditions = paths.get_conditions('Alessandro', 'eStim')

# %%
aless[0:10]
# Out:
#                                             datapath state  depth  \
# 0  Data\chronic\CNPIX5-Alessandro\8-31-2020\8-31-...  Wake    1.1
# 1  Data\chronic\CNPIX5-Alessandro\8-31-2020\8-31-...  NREM    1.1
# 2  Data\chronic\CNPIX5-Alessandro\8-31-2020\8-31-...   REM    1.1
# 3  Data\chronic\CNPIX5-Alessandro\9-8-2020\9-25-2...  Sevo    1.1
# 4  Data\chronic\CNPIX5-Alessandro\9-2-2020\9-2-20...   Dex    1.1
# 5  Data\chronic\CNPIX5-Alessandro\9-21-2020\9-21-...   Ket    1.1
#
#                                             stimpath  N_trials  \
# 0  Data\CNPIX5-Alessandro\eStim\8-31-2020_WEst_g0...       100
# 1  Data\CNPIX5-Alessandro\eStim\8-31-2020_SleepSt...       100
# 2  Data\CNPIX5-Alessandro\eStim\8-31-2020_REMStim...       100
# 3  Data\CNPIX5-Alessandro\eStim\9-25-2020_Sevo_g0...       100
# 4  Data\CNPIX5-Alessandro\eStim\9-2-2020_Dex_g0\9...       100
# 5  Data\CNPIX5-Alessandro\eStim\9-21-2020-Keta-St...       100
#
#    trials_reordered_BL
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN

# %%
# add condition dir to run path

for cond in conditions: 
    pathname = paths.get_sglx_style_datapaths('Alessandro', cond, 'ap.bin')[0]
    rundir = pathname.parents[1]
    run = rundir.name
    for i, row in aless.iterrows():
        path = row['datapath']
        assert rundir not in aless.columns or aless.iloc[i, 'rundir'] is None 
        if run in path:
            aless.loc[i, 'rundir'] = rundir
            aless.loc[i, 'condition'] = cond

# %%
aless
# Out:
#                                             datapath state  depth  \
# 0  Data\chronic\CNPIX5-Alessandro\8-31-2020\8-31-...  Wake    1.1
# 1  Data\chronic\CNPIX5-Alessandro\8-31-2020\8-31-...  NREM    1.1
# 2  Data\chronic\CNPIX5-Alessandro\8-31-2020\8-31-...   REM    1.1
# 3  Data\chronic\CNPIX5-Alessandro\9-8-2020\9-25-2...  Sevo    1.1
# 4  Data\chronic\CNPIX5-Alessandro\9-2-2020\9-2-20...   Dex    1.1
# 5  Data\chronic\CNPIX5-Alessandro\9-21-2020\9-21-...   Ket    1.1
#
#                                             stimpath  N_trials  \
# 0  Data\CNPIX5-Alessandro\eStim\8-31-2020_WEst_g0...       100
# 1  Data\CNPIX5-Alessandro\eStim\8-31-2020_SleepSt...       100
# 2  Data\CNPIX5-Alessandro\eStim\8-31-2020_REMStim...       100
# 3  Data\CNPIX5-Alessandro\eStim\9-25-2020_Sevo_g0...       100
# 4  Data\CNPIX5-Alessandro\eStim\9-2-2020_Dex_g0\9...       100
# 5  Data\CNPIX5-Alessandro\eStim\9-21-2020-Keta-St...       100
#
#    trials_reordered_BL                                             rundir  \
# 0                  NaN  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 1                  NaN  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 2                  NaN  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 3                  NaN  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 4                  NaN  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
# 5                  NaN  /Volumes/neuropixel_archive/Data/chronic/CNPIX...
#
#               condition
# 0  8-31-2020_Wake_imec0
# 1  8-31-2020_NREM_imec0
# 2   8-31-2020_REM_imec0
# 3  9-25-2020_Sevo_imec0
# 4    9-2-2020_Dex_imec0
# 5   9-21-2020_Ket_imec0

# %%
aless['condition']
# Out:
# 0    8-31-2020_Wake_imec0
# 1    8-31-2020_NREM_imec0
# 2     8-31-2020_REM_imec0
# 3    9-25-2020_Sevo_imec0
# 4      9-2-2020_Dex_imec0
# 5     9-21-2020_Ket_imec0
# Name: condition, dtype: object

# %%
aless['rundir'][0]
# Out:
# PosixPath('/Volumes/neuropixel_archive/Data/chronic/CNPIX5-Alessandro/8-31-2020/8-31-2020_WEst_g0')

# %%
aless['stimpath'][0]
# Out:
# 'Data\\CNPIX5-Alessandro\\eStim\\8-31-2020_WEst_g0\\8-31-2020_WEst_g0_imec0\\stim.txt'

# %%
import numpy as np

# for i, row in eugene.iterrows():
for cond in conditions:
    for i, row in aless.iterrows():
        if row['condition'] not in cond:
            continue
        stimpath = row['stimpath'].split('CNPIX5-Alessandro')[1].replace('\\', '/').replace("'", '')

        stimpath = Path('/Volumes/neuropixel/Data/CNPIX5-Alessandro' + stimpath)
        print(stimpath, stimpath.exists())

        stim_times = pd.read_csv(stimpath, header=None)

        df = pd.DataFrame({'sglx_stim_time': np.concatenate(stim_times.values), 'stim_state': row['state']})
        print(df[0:5])

    #     dfpath = path.get_filename()
        df_path = paths.get_datapath('Alessandro', cond, 'stim_times.csv')
        print(df_path)

        df_path.parent.mkdir()
        df.to_csv(df_path, index=False)

    #     if i > 3:
    #         break
    #     stimtimes =
# Out:
# /Volumes/neuropixel/Data/CNPIX5-Alessandro/eStim/8-31-2020_REMStim_g0/8-31-2020_REMStim_g0_imec0/stim.txt True
#    sglx_stim_time stim_state
# 0       896.60990        REM
# 1      1545.44850        REM
# 2      1533.44860        REM
# 3       867.61875        REM
# 4      1509.35420        REM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX5-Alessandro/8-31-2020_REM_imec0/stim_times.csv
# /Volumes/neuropixel/Data/CNPIX5-Alessandro/eStim/8-31-2020_SleepStim_g0/8-31-2020_SleepStim_g0_imec0/stim.txt True
#    sglx_stim_time stim_state
# 0      1276.56870       NREM
# 1      1629.56990       NREM
# 2      1117.61230       NREM
# 3      1531.57540       NREM
# 4       353.34742       NREM
# /Volumes/neuropixel/Data/tom/catgt/CNPIX5-Alessandro/8-31-2020_NREM_imec0/stim_times.csv
# /Volumes/neuropixel/Data/CNPIX5-Alessandro/eStim/8-31-2020_WEst_g0/8-31-2020_WEst_g0_imec0/stim.txt True
#    sglx_stim_time stim_state
# 0       2421.9350       Wake
# 1       2425.9350       Wake
# 2       1046.3364       Wake
# 3       1207.7638       Wake
# 4       2522.5296       Wake
# /Volumes/neuropixel/Data/tom/catgt/CNPIX5-Alessandro/8-31-2020_Wake_imec0/stim_times.csv
# /Volumes/neuropixel/Data/CNPIX5-Alessandro/eStim/9-25-2020_Sevo_g0/9-25-2020_Sevo_g0_imec0/stim.txt True
#    sglx_stim_time stim_state
# 0       551.84925       Sevo
# 1      1177.99400       Sevo
# 2      1061.99510       Sevo
# 3       765.89421       Sevo
# 4      1057.99520       Sevo
# /Volumes/neuropixel/Data/tom/catgt/CNPIX5-Alessandro/9-25-2020_Sevo_imec0/stim_times.csv
# /Volumes/neuropixel/Data/CNPIX5-Alessandro/eStim/9-2-2020_Dex_g0/9-2-2020_Dex_g0_imec0/stim.txt True
#    sglx_stim_time stim_state
# 0       1907.7816        Dex
# 1       1611.4335        Dex
# 2       2051.7802        Dex
# 3       1967.7810        Dex
# 4       1559.4340        Dex
# /Volumes/neuropixel/Data/tom/catgt/CNPIX5-Alessandro/9-2-2020_Dex_imec0/stim_times.csv
# /Volumes/neuropixel/Data/CNPIX5-Alessandro/eStim/9-21-2020-Keta-Stim_g0/stim.txt True
#    sglx_stim_time stim_state
# 0       2820.9133        Ket
# 1       2471.3153        Ket
# 2       2641.3138        Ket
# 3       2850.9132        Ket
# 4       2646.3135        Ket
# /Volumes/neuropixel/Data/tom/catgt/CNPIX5-Alessandro/9-21-2020_Ket_imec0/stim_times.csv

# %%
# Giuseppe Combined

# %%
combined_cond = '8-31-2020_REMmerged_imec0'
conditions =  paths.load_datapath_yaml()['Alessandro'][combined_cond]
# conds = paths.get_sglx_style_datapaths('Giuseppe', '12-27-2020_Wake_NREM_REM_depth1.5_imec0', 'dummy')
print(conditions)
# Out:
# ['8-31-2020_REM_imec0', '8-31-2020_REM2_imec0']

# %%
# dfs = []
# start_time = 0
# for cond in conditions:
#     path = (paths.get_datapath('Alessandro', cond, 'stim_times.csv'))
#     df = pd.read_csv(path)
#     df['sglx_stim_time'] = df['sglx_stim_time'] + start_time
#     dfs.append(df)
# #     binpaths = paths.get_sglx_style_datapaths('Giuseppe', cond, 'ap.bin', catgt_data=True)
#     assert len(binpaths) == 1
#     start_time = float(sglx_utils.get_meta(binpaths[0])['fileTimeSecs'])
# df_combined = pd.concat(dfs)
# df_combined
    
# #     end_time 
# #     df
# #     print(path.exists())
# #     print(path)
# Out:
# -------------------------------------------------------------------
# FileNotFoundError                 Traceback (most recent call last)
# <ipython-input-76-18b87a47c1c7> in <module>
#       3 for cond in conditions:
#       4     path = (paths.get_datapath('Alessandro', cond, 'stim_times.csv'))
# ----> 5     df = pd.read_csv(path)
#       6     df['sglx_stim_time'] = df['sglx_stim_time'] + start_time
#       7     dfs.append(df)
#
# /Volumes/scratch/neuropixels/miniconda3/envs/neuropix/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /Volumes/scratch/neuropixels/miniconda3/envs/neuropix/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# /Volumes/scratch/neuropixels/miniconda3/envs/neuropix/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# /Volumes/scratch/neuropixels/miniconda3/envs/neuropix/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# /Volumes/scratch/neuropixels/miniconda3/envs/neuropix/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/neuropixel/Data/tom/catgt/CNPIX5-Alessandro/8-31-2020_REM2_imec0/stim_times.csv'

# %%
# Giuseppe

# %%
# Combined

# %%
combined_cond = '12-27-2020_Wake_NREM_REM_depth1.5_imec0'
conditions =  paths.load_datapath_yaml()['Giuseppe'][combined_cond]
# conds = paths.get_sglx_style_datapaths('Giuseppe', '12-27-2020_Wake_NREM_REM_depth1.5_imec0', 'dummy')
# conds

# %%
dfs = []
start_time = 0
for cond in conditions:
    path = (paths.get_sglx_style_datapaths('Giuseppe', cond, 'dummy', catgt_data=True)[0].parents[1])/'stim_times.csv'
    df = pd.read_csv(path)
    df['sglx_stim_time'] = df['sglx_stim_time'] + start_time
    dfs.append(df)
    binpaths = paths.get_sglx_style_datapaths('Giuseppe', cond, 'ap.bin', catgt_data=True)
    assert len(binpaths) == 1
    start_time = float(sglx_utils.get_meta(binpaths[0])['fileTimeSecs'])
df_combined = pd.concat(dfs)
    
#     end_time 
#     df
#     print(path.exists())
#     print(path)

# %%
save_path = paths.get_datapath('Giuseppe', combined_cond, 'stim_times.csv')
save_path
# Out:
# PosixPath('/Volumes/neuropixel/Data/tom/catgt/CNPIX7-Giuseppe/12-27-2020_Wake_NREM_REM_depth1.5_imec0/stim_times.csv')

# %%
df_combined.to_csv(save_path, index=False)

# %% [markdown]
# # Channel depths

# %%
# metapath = Path('/Volumes/scratch/neuropixels/data/tom/catgt/CNPIX4-Doppio/3-17-2020/catgt_3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_tcat.imec0.ap.meta')
metapath = Path('/Volumes/scratch/neuropixels/data/tom/catgt/CNPIX8-Allan/3-1-2021/catgt_3-1-2021_C_g0/3-1-2021_C_g0_imec1/3-1-2021_C_g0_tcat.imec1.ap.meta')

# %%
from ecephys_analyses.data.utils import depth_from_channel

depth_from_channel(metapath, [287, 176, 291])
# (array([286]),)
# (array([175]),)
# (array([290]
# Out:
# 0
# 1 820.0
# 2 840.0
# 3 860.0
# 4 880.0
# 5 900.0
# 6 920.0
# 7 940.0
# 8 960.0
# 9 980.0
# 10 1000.0
# 11 1020.0
# 12 1040.0
# 13 1060.0
# 14 1080.0
# 15 1100.0
# 16 1120.0
# 17 1140.0
# 18 1160.0
# 19 1180.0
# 20 1200.0
# 21 1220.0
# 22 1240.0
# 23 1260.0
# 24 1280.0
# 25 1300.0
# 26 1320.0
# 27 1340.0
# 28 1360.0
# 29 1380.0
# 30 1400.0
# 31 1420.0
# 32 1440.0
# 33 1460.0
# 34 1480.0
# 35 1500.0
# 36 1520.0
# 37 1540.0
# 38 1560.0
# 39 1580.0
# 40 1600.0
# 41 1620.0
# 42 1640.0
# 43 1660.0
# 44 1680.0
# 45 1700.0
# 46 1720.0
# 47 1740.0
# 48 1760.0
# 49 1780.0
# 50 1800.0
# 51 1820.0
# 52 1840.0
# 53 1860.0
# 54 1880.0
# 55 1900.0
# 56 1920.0
# 57 1940.0
# 58 1960.0
# 59 1980.0
# 60 2000.0
# 61 2020.0
# 62 2040.0
# 63 2060.0
# 64 2080.0
# 65 2100.0
# 66 2120.0
# 67 2140.0
# 68 2160.0
# 69 2180.0
# 70 2200.0
# 71 2220.0
# 72 2240.0
# 73 2260.0
# 74 2280.0
# 75 2300.0
# 76 2320.0
# 77 2340.0
# 78 2360.0
# 79 2380.0
# 80 2400.0
# 81 2420.0
# 82 2440.0
# 83 2460.0
# 84 2480.0
# 85 2500.0
# 86 2520.0
# 87 2540.0
# 88 2560.0
# 89 2580.0
# 90 2600.0
# 91 2620.0
# 92 2640.0
# 93 2660.0
# 94 2680.0
# 95 2700.0
# 96 2720.0
# 97 2740.0
# 98 2760.0
# 99 2780.0
# 100 2800.0
# 101 2820.0
# 102 2840.0
# 103 2860.0
# 104 2880.0
# 105 2900.0
# 106 2920.0
# 107 2940.0
# 108 2960.0
# 109 2980.0
# 110 3000.0
# 111 3020.0
# 112 3040.0
# 113 3060.0
# 114 3080.0
# 115 3100.0
# 116 3120.0
# 117 3140.0
# 118 3160.0
# 119 3180.0
# 120 3200.0
# 121 3220.0
# 122 3240.0
# 123 3260.0
# 124 3280.0
# 125 3300.0
# 126 3320.0
# 127 3340.0
# 128 3360.0
# 129 3380.0
# 130 3400.0
# 131 3420.0
# 132 3440.0
# 133 3460.0
# 134 3480.0
# 135 3500.0
# 136 3520.0
# 137 3540.0
# 138 3560.0
# 139 3580.0
# 140 3600.0
# 141 3620.0
# 142 3640.0
# 143 3660.0
# 144 3680.0
# 145 3700.0
# 146 3720.0
# 147 3740.0
# 148 3760.0
# 149 3780.0
# 150 3800.0
# 151 3820.0
# 152 3840.0
# 153 3860.0
# 154 3880.0
# 155 3900.0
# 156 3920.0
# 157 3940.0
# 158 3960.0
# 159 3980.0
# 160 4000.0
# 161 4020.0
# 162 4040.0
# 163 4060.0
# 164 4080.0
# 165 4100.0
# 166 4120.0
# 167 4140.0
# 168 4160.0
# 169 4180.0
# 170 4200.0
# 171 4220.0
# 172 4240.0
# 173 4260.0
# 174 4280.0
# 175 4300.0
# 176 4320.0
# 177 4340.0
# 178 4360.0
# 179 4380.0
# 180 4400.0
# 181 4420.0
# 182 4440.0
# 183 4460.0
# 184 4480.0
# 185 4500.0
# 186 4520.0
# 187 4540.0
# 188 4560.0
# 189 4580.0
# 190 4600.0
# 191 4620.0
# 192 4640.0
# 193 4660.0
# 194 4680.0
# 195 4700.0
# 196 4720.0
# 197 4740.0
# 198 4760.0
# 199 4780.0
# 200 4800.0
# 201 4820.0
# 202 4840.0
# 203 4860.0
# 204 4880.0
# 205 4900.0
# 206 4920.0
# 207 4940.0
# 208 4960.0
# 209 4980.0
# 210 5000.0
# 211 5020.0
# 212 5040.0
# 213 5060.0
# 214 5080.0
# 215 5100.0
# 216 5120.0
# 217 5140.0
# 218 5160.0
# 219 5180.0
# 220 5200.0
# 221 5220.0
# 222 5240.0
# 223 5260.0
# 224 5280.0
# 225 5300.0
# 226 5320.0
# 227 5340.0
# 228 5360.0
# 229 5380.0
# 230 5400.0
# 231 5420.0
# 232 5440.0
# 233 5460.0
# 234 5480.0
# 235 5500.0
# 236 5520.0
# 237 5540.0
# 238 5560.0
# 239 5580.0
# 240 5600.0
# 241 5620.0
# 242 5640.0
# 243 5660.0
# 244 5680.0
# 245 5700.0
# 246 5720.0
# 247 5740.0
# 248 5760.0
# 249 5780.0
# 250 5800.0
# 251 5820.0
# 252 5840.0
# 253 5860.0
# 254 5880.0
# 255 5900.0
# 256 5920.0
# 257 5940.0
# 258 5960.0
# 259 5980.0
# 260 6000.0
# 261 6020.0
# 262 6040.0
# 263 6060.0
# 264 6080.0
# 265 6100.0
# 266 6120.0
# 267 6140.0
# 268 6160.0
# 269 6180.0
# 270 6200.0
# 271 6220.0
# 272 6240.0
# 273 6260.0
# 274 6280.0
# 275 6300.0
# 276 6320.0
# 277 6340.0
# 278 6360.0
# 279 6380.0
# 280 6400.0
# 281 6420.0
# 282 6440.0
# 283 6460.0
# 284 6480.0
# 285 6500.0
# 286 6520.0
# 287 6540.0
# 288 6560.0
# 289 6580.0
# 290 6600.0
# 291 6620.0
# 292 6640.0
# 293 6660.0
# 294 6680.0
# 295 6700.0
# 296 6720.0
# 297 6740.0
# 298 6760.0
# 299 6780.0
# 300 6800.0
# 301 6820.0
# 302 6840.0
# 303 6860.0
# 304 6880.0
# 305 6900.0
# 306 6920.0
# 307 6940.0
# 308 6960.0
# 309 6980.0
# 310 7000.0
# 311 7020.0
# 312 7040.0
# 313 7060.0
# 314 7080.0
# 315 7100.0
# 316 7120.0
# 317 7140.0
# 318 7160.0
# 319 7180.0
# 320 7200.0
# 321 7220.0
# 322 7240.0
# 323 7260.0
# 324 7280.0
# 325 7300.0
# 326 7320.0
# 327 7340.0
# 328 7360.0
# 329 7380.0
# 330 7400.0
# 331 7420.0
# 332 7440.0
# 333 7460.0
# 334 7480.0
# 335 7500.0
# 336 7520.0
# 337 7540.0
# 338 7560.0
# 339 7580.0
# 340 7600.0
# 341 7620.0
# 342 7640.0
# 343 7660.0
# 344 7680.0
# 345 7700.0
# 346 7720.0
# 347 7740.0
# 348 7760.0
# 349 7780.0
# 350 7800.0
# 351 7820.0
# 352 7840.0
# 353 7860.0
# 354 7880.0
# 355 7900.0
# 356 7920.0
# 357 7940.0
# 358 7960.0
# 359 7980.0
# 360 8000.0
# 361 8020.0
# 362 8040.0
# 363 8060.0
# 364 8080.0
# 365 8100.0
# 366 8120.0
# 367 8140.0
# 368 8160.0
# 369 8180.0
# 370 8200.0
# 371 8220.0
# 372 8240.0
# 373 8260.0
# 374 8280.0
# 375 8300.0
# 376 8320.0
# 377 8340.0
# 378 8360.0
# 379 8380.0
# 380 8400.0
# 381 8420.0
# 382 8440.0
# 383 8460.0
# 384 8480.0
# array([6540., 4320., 6620.])

# %% [markdown]
# # Copy concatenated hypnograms to condition dir

# %%
from pathlib import Path
import pandas as pd
from ecephys_analyses.data import paths
from ecephys import scoring

# %%
condition_groups = [
    ('Doppio', 'SD'),
    ('Allan', 'SD'),
    ('Luigi', 'SD'),
]

data_conditions = []
for subject, condition_group in condition_groups:
    data_conditions += [
        (subject, cond)
        for cond in paths.get_conditions(subject, condition_group)
    ]
print(f'Data condition N={len(data_conditions)} (Looks good?): {data_conditions}')
# Out:
# Data condition N=10 (Looks good?): [('Doppio', 'baseline-sleep-2h-circadian-match_imec0'), ('Doppio', 'baseline-sleep-2h-circadian-match_imec1'), ('Doppio', 'recovery-sleep-2h_imec0'), ('Doppio', 'recovery-sleep-2h_imec1'), ('Allan', 'baseline-sleep-2h-circadian-match_imec0'), ('Allan', 'baseline-sleep-2h-circadian-match_imec1'), ('Allan', 'recovery-sleep-2h_imec0'), ('Allan', 'recovery-sleep-2h_imec1'), ('Luigi', 'baseline-sleep-2h-circadian-match_imec0'), ('Luigi', 'recovery-sleep-2h_imec0')]

# %%
for subject, condition in data_conditions:
    hyp_paths = paths.get_hypno_datapaths(subject, condition)
    print(subject, condition)
    for prb in ['imec0', 'imec1']:
        try:
            print(f'Try loading hyp saved for {prb}...', end='')
            imec_hyp_paths = [
                Path(str(p).replace('imec0', 'imec1').replace('imec1', prb))
                for p in hyp_paths
            ]
            print(imec_hyp_path)
            hyp = scoring.load_consecutive_visbrain_hypnograms(
                imec_hyp_paths
            )
            found=True
            print('Found it!')
            break
        except FileNotFoundError:
            print('not found')
            found=False
            continue
    if not found:
        continue
    print("Save in condition dir")
    savepath = paths.get_datapath(subject, condition, 'hypnogram.csv')
    savepath.parent.mkdir(exist_ok=True)
    print(savepath)
    hyp.to_csv(savepath, index=False)
    print("Done")
    print('\n\n')
# Out:
# Doppio baseline-sleep-2h-circadian-match_imec0
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX4-Doppio/baseline-sleep-2h-circadian-match_imec0/hypnogram.csv
# Done
#
#
#
# Doppio baseline-sleep-2h-circadian-match_imec1
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX4-Doppio/baseline-sleep-2h-circadian-match_imec1/hypnogram.csv
# Done
#
#
#
# Doppio recovery-sleep-2h_imec0
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX4-Doppio/recovery-sleep-2h_imec0/hypnogram.csv
# Done
#
#
#
# Doppio recovery-sleep-2h_imec1
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX4-Doppio/recovery-sleep-2h_imec1/hypnogram.csv
# Done
#
#
#
# Allan baseline-sleep-2h-circadian-match_imec0
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found
# Try loading hyp saved for imec1...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX8-Allan/baseline-sleep-2h-circadian-match_imec0/hypnogram.csv
# Done
#
#
#
# Allan baseline-sleep-2h-circadian-match_imec1
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found
# Try loading hyp saved for imec1...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX8-Allan/baseline-sleep-2h-circadian-match_imec1/hypnogram.csv
# Done
#
#
#
# Allan recovery-sleep-2h_imec0
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found
# Try loading hyp saved for imec1...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX8-Allan/recovery-sleep-2h_imec0/hypnogram.csv
# Done
#
#
#
# Allan recovery-sleep-2h_imec1
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found
# Try loading hyp saved for imec1...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# Found it!
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX8-Allan/recovery-sleep-2h_imec1/hypnogram.csv
# Done
#
#
#
# Luigi baseline-sleep-2h-circadian-match_imec0
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found
# Try loading hyp saved for imec1...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found
# Luigi recovery-sleep-2h_imec0
# Try loading hyp saved for imec0...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found
# Try loading hyp saved for imec1...[PosixPath('/Volumes/neuropixel/Data/CNPIX4-Doppio/3-17-2020/3-17-2020_g0/3-17-2020_g0_imec0/3-17-2020_g0_t3.imec0.hypnogram.txt')]
# not found

# %%
hyp = scoring.load_consecutive_visbrain_hypnograms(
    paths.get_hypno_datapaths('Allan', 'baseline-sleep-2h-circadian-match_imec1')
)

# %%
hyp
# Out:
#        state     end_time   start_time   duration
# 0         N2    59.990002     0.000000  59.990002
# 1         IS    77.989998    59.990002  17.999996
# 2        REM   101.989998    77.989998  24.000000
# 3      Trans   107.989998   101.989998   6.000000
# 4    Arousal   125.989998   107.989998  18.000000
# ..       ...          ...          ...        ...
# 136    Trans  7109.979980  7091.979980  18.000000
# 137     Wake  7145.979980  7109.979980  36.000000
# 138    Trans  7163.979980  7145.979980  18.000000
# 139  Arousal  7175.979980  7163.979980  12.000000
# 140    Trans  7199.979980  7175.979980  24.000000
#
# [234 rows x 4 columns]

# %% [markdown]
# # Copy concatenated hypnograms to "multiple" condition dir

# %%
from pathlib import Path
import pandas as pd
from ecephys_analyses.data import paths
from ecephys import scoring

# %%
condition_groups = [
    ('Doppio', 'SD'),
    ('Allan', 'SD'),
#     ('Luigi', 'SD'),
]

data_conditions = []
for subject, condition_group in condition_groups:
    data_conditions += [
        (subject, cond)
        for cond in paths.get_conditions(subject, condition_group)
    ]
print(f'Data condition N={len(data_conditions)} (Looks good?): {data_conditions}')
# Out:
# Data condition N=3 (Looks good?): [('Doppio', 'sleep-homeostasis-2h_imec1'), ('Allan', 'sleep-homeostasis-2h_imec0'), ('Allan', 'sleep-homeostasis-2h_imec1')]

# %%
from ecephys_analyses.data.paths import get_subconditions, is_combined_condition
from ecephys.scoring import load_consecutive_csv_hypnograms

for subject, condition in data_conditions:

    if is_combined_condition(subject, condition):
        subconditions = get_subconditions(subject, condition)
        hyp = load_consecutive_csv_hypnograms(
            [
                paths.get_datapath(subject, subcondition, 'hypnogram.csv')
                 for subcondition in subconditions
            ],
            conditions = subconditions,
        )
        print("Save in condition dir")
        savepath = paths.get_datapath(subject, condition, 'hypnogram.csv')
        savepath.parent.mkdir(exist_ok=True)
        print(savepath)
        hyp.to_csv(savepath, index=False)
        print("Done")
        
    # subconditions = get_subconditions('Doppio', 'baseline-sleep-2h-circadian-match_imec1')
    else:
        print(f"Pass {subject} {condition}: Not 'combined' condition")
# Out:
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX4-Doppio/sleep-homeostasis-2h_imec1/hypnogram.csv
# Done
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX8-Allan/sleep-homeostasis-2h_imec0/hypnogram.csv
# Done
# Save in condition dir
# /Volumes/scratch/neuropixels/data/tom/catgt/CNPIX8-Allan/sleep-homeostasis-2h_imec1/hypnogram.csv
# Done

# %%
hyp
# Out:
#        state      end_time    start_time   duration  \
# 0         N2     59.990002      0.000000  59.990002
# 1         IS     77.989998     59.990002  17.999996
# 2        REM    101.989998     77.989998  24.000000
# 3      Trans    107.989998    101.989998   6.000000
# 4    Arousal    125.989998    107.989998  18.000000
# ..       ...           ...           ...        ...
# 169       N2  14345.959961  14309.959961  36.000000
# 170  Arousal  14357.959961  14345.959961  12.000000
# 171    Trans  14369.959961  14357.959961  12.000000
# 172       N1  14381.959961  14369.959961  12.000000
# 173       IS  14399.959961  14381.959961  18.000000
#
#                                    condition
# 0    baseline-sleep-2h-circadian-match_imec1
# 1    baseline-sleep-2h-circadian-match_imec1
# 2    baseline-sleep-2h-circadian-match_imec1
# 3    baseline-sleep-2h-circadian-match_imec1
# 4    baseline-sleep-2h-circadian-match_imec1
# ..                                       ...
# 169                  recovery-sleep-2h_imec1
# 170                  recovery-sleep-2h_imec1
# 171                  recovery-sleep-2h_imec1
# 172                  recovery-sleep-2h_imec1
# 173                  recovery-sleep-2h_imec1
#
# [408 rows x 5 columns]
