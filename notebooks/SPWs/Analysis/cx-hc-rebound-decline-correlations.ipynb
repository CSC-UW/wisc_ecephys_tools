# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(
    {
        "subject": ["Segundo", "Valentino", "Doppio", "Alessandro", "Allan"],
        "cx_rebound": [174.701, 103.316, 157.888, 108.193, 188.973],
        "hc_rebound": [42.226, 36.078, 43.596, 41.053, 33.832],
        "cx_decline": [130.479, 79.956, 103.725, 71.808, 179.685],
        "hc_decline": [37.733, 22.705, 43.898, 50.438, 38.512],
    }
).set_index("subject")
print(df.to_markdown())
# Out:
# | subject    |   cx_rebound |   hc_rebound |   cx_decline |   hc_decline |
# |:-----------|-------------:|-------------:|-------------:|-------------:|
# | Segundo    |      174.701 |       42.226 |      130.479 |       37.733 |
# | Valentino  |      103.316 |       36.078 |       79.956 |       22.705 |
# | Doppio     |      157.888 |       43.596 |      103.725 |       43.898 |
# | Alessandro |      108.193 |       41.053 |       71.808 |       50.438 |
# | Allan      |      188.973 |       33.832 |      179.685 |       38.512 |

# %%
sns.pairplot(df, diag_kind='None')

# %%
sns.pairplot(df, diag_kind='None', kind='reg', plot_kws=dict(ci=None))

# %%
print(df.corr(method='pearson').to_markdown())
# Out:
# |            |   cx_rebound |   hc_rebound |   cx_decline |   hc_decline |
# |:-----------|-------------:|-------------:|-------------:|-------------:|
# | cx_rebound |    1         |   -0.0441786 |    0.915473  |    0.165802  |
# | hc_rebound |   -0.0441786 |    1         |   -0.435636  |    0.537983  |
# | cx_decline |    0.915473  |   -0.435636  |    1         |   -0.0181772 |
# | hc_decline |    0.165802  |    0.537983  |   -0.0181772 |    1         |
